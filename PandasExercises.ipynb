# %%
# Wednesday Exercise 1
import pandas as pd
import re

df = pd.read_csv("./imdb_top_1000.csv")
# getting rid of useless columns
df.drop(columns=['Poster_Link','Overview'], inplace=True)
df.loc[df['Released_Year'] == "PG"]
# Out:
#     Series_Title Released_Year Certificate  Runtime  \
# 966    Apollo 13            PG           U  140 min
#
#                          Genre  IMDB_Rating  Meta_score    Director  \
# 966  Adventure, Drama, History          7.6        77.0  Ron Howard
#
#          Star1        Star2        Star3        Star4  No_of_Votes  \
# 966  Tom Hanks  Bill Paxton  Kevin Bacon  Gary Sinise       269197
#
#            Gross
# 966  173,837,933

# %%
# getting oldest movie
oldest_movie_row = df['Released_Year'].idxmin()
oldest_movie_title = df.iloc[oldest_movie_row]["Series_Title"]
# Out:
# 'Das Cabinet des Dr. Caligari'

# %%
# getting newest movie
# newest_movie_row = df['Released_Year'].idxmax()
# newest_movie_row = df.iloc[newest_movie_row]
df[pd.to_numeric(df['Released_Year'], errors='coerce').notnull()].nlargest(1, 'Released_Year')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 4
#       1 # getting newest movie
#       2 # newest_movie_row = df['Released_Year'].idxmax()
#       3 # newest_movie_row = df.iloc[newest_movie_row]
# ----> 4 df[pd.to_numeric(df['Released_Year'], errors='coerce').notnull()].nlargest(1, 'Released_Year')
#
# File c:\Users\sxie0\Documents\SkillStorm\.venv\lib\site-packages\pandas\core\frame.py:7644, in DataFrame.nlargest(self, n, columns, keep)
#    7525 def nlargest(
#    7526     self, n: int, columns: IndexLabel, keep: NsmallestNlargestKeep = "first"
#    7527 ) -> DataFrame:
#    7528     """
#    7529     Return the first `n` rows ordered by `columns` in descending order.
#    7530
#    (...)
#    7642     Brunei      434000    12128      BN
#    7643     """
# -> 7644     return selectn.SelectNFrame(self, n=n, keep=keep, columns=columns).nlargest()
#
# ...

# %%
# Top 10 IMDB Rating Movies

df.sort_values('IMDB_Rating', ascending=False).head(10)
# Out:
#                                      Series_Title Released_Year Certificate  \
# 0                        The Shawshank Redemption          1994           A
# 1                                   The Godfather          1972           A
# 4                                    12 Angry Men          1957           U
# 2                                 The Dark Knight          2008          UA
# 3                          The Godfather: Part II          1974           A
# 5   The Lord of the Rings: The Return of the King          2003           U
# 7                                Schindler's List          1993           A
# 6                                    Pulp Fiction          1994           A
# 8                                       Inception          2010          UA
# 12                Il buono, il brutto, il cattivo          1966           A
#
#     Runtime                      Genre  IMDB_Rating  Meta_score  \
# 0   142 min                      Drama          9.3        80.0
# ...

# %%
# Top movie for each genre
df['Genre']
# Out:
# 0                         Drama
# 1                  Crime, Drama
# 2          Action, Crime, Drama
# 3                  Crime, Drama
# 4                  Crime, Drama
#                  ...
# 995      Comedy, Drama, Romance
# 996              Drama, Western
# 997         Drama, Romance, War
# 998                  Drama, War
# 999    Crime, Mystery, Thriller
# Name: Genre, Length: 1000, dtype: object

# %%
# Director with the most movies
df
